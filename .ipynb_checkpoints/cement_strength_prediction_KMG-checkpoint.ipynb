# %% [markdown]
# ## Cement Strength Prediction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dir = './Concrete Compressive Strength with Periods.csv'
df = pd.read_csv(dir)
df.drop('Unnamed: 0', axis=1, inplace=True)
df.columns
# Out:
# Index(['Cement (component 1)(kg in a m^3 mixture)',
#        'Blast Furnace Slag (component 2)(kg in a m^3 mixture)',
#        'Fly Ash (component 3)(kg in a m^3 mixture)',
#        'Water  (component 4)(kg in a m^3 mixture)',
#        'Superplasticizer (component 5)(kg in a m^3 mixture)',
#        'Coarse Aggregate  (component 6)(kg in a m^3 mixture)',
#        'Fine Aggregate (component 7)(kg in a m^3 mixture)', 'Age (day)',
#        'Period (term)', 'Concrete compressive strength(MPa, megapascals) '],
#       dtype='object')

# %%
df.columns = ['Cement','Slag','Fly_ash','water','SuperP','C_agg','F_agg','Age','Period', 'C_str']

# %%
df['w/c'] = df['water']/df['Cement']
df['agg'] = (df['C_agg']+df['F_agg'])/2
df.drop(['water', 'Cement', 'C_agg', 'F_agg'], axis=1, inplace=True)

# %%
print(df.head())
print(df.tail())
# Out:
#     Slag  Fly_ash  SuperP  Age Period      C_str       w/c     agg
# 0    0.0      0.0     2.5   28    mid  79.986111  0.300000  858.00
# 1    0.0      0.0     2.5   28    mid  61.887366  0.300000  865.50
# 2  142.5      0.0     0.0  270   long  40.269535  0.685714  763.00
# 3  142.5      0.0     0.0  365   long  41.052780  0.685714  763.00
# 4  132.4      0.0     0.0  360   long  44.296075  0.966767  901.95
#        Slag  Fly_ash  SuperP  Age Period      C_str       w/c     agg
# 1025  116.0     90.3     8.9   28    mid  44.284354  0.649783  819.20
# 1026    0.0    115.6    10.4   28    mid  31.178794  0.608318  815.65
# 1027  139.4    108.6     6.1   28    mid  23.696601  1.297643  836.20
# 1028  186.7      0.0    11.3   28    mid  32.768036  1.103708  889.25
# 1029  100.5     78.3     8.6   28    mid  32.401235  0.768877  813.00

# %%
print(df.shape)
print(df.dtypes)
# Out:
# (1030, 8)
# Slag       float64
# Fly_ash    float64
# SuperP     float64
# Age          int64
# Period      object
# C_str      float64
# w/c        float64
# agg        float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Slag     1030 non-null   float64
#  1   Fly_ash  1030 non-null   float64
#  2   SuperP   1030 non-null   float64
#  3   Age      1030 non-null   int64
#  4   Period   1030 non-null   object
#  5   C_str    1030 non-null   float64
#  6   w/c      1030 non-null   float64
#  7   agg      1030 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 64.5+ KB

# %%
df.describe()
# Out:
#               Slag      Fly_ash       SuperP          Age        C_str  \
# count  1030.000000  1030.000000  1030.000000  1030.000000  1030.000000
# mean     73.895485    54.187136     6.203112    45.662136    35.817836
# std      86.279104    63.996469     5.973492    63.169912    16.705679
# min       0.000000     0.000000     0.000000     1.000000     2.331808
# 25%       0.000000     0.000000     0.000000     7.000000    23.707115
# 50%      22.000000     0.000000     6.350000    28.000000    34.442774
# 75%     142.950000   118.270000    10.160000    56.000000    46.136287
# max     359.400000   200.100000    32.200000   365.000000    82.599225
#
#                w/c          agg
# count  1030.000000  1030.000000
# mean      0.748269   873.248738
# std       0.314005    50.616611
# min       0.266893   728.500000
# 25%       0.533333   839.500000
# 50%       0.675349   876.450000
# 75%       0.935014   913.972500
# max       1.882353   985.000000

# %%
print(df.isnull().sum())
print(df.isnull().sum().sum())
# Out:
# Slag       0
# Fly_ash    0
# SuperP     0
# Age        0
# Period     0
# C_str      0
# w/c        0
# agg        0
# dtype: int64
# 0

# %%
print(df['Period'].value_counts())
sns.countplot(x = df['Period'])
plt.show()
# Out:
# Period
# mid      487
# long     281
# short    262
# Name: count, dtype: int64

# %%
df.hist('C_str', grid=False)
plt.title('Concrete compressive strength')
plt.show()

# %%
sns.boxplot(x=df['Period'], y=df['C_str'])
sns.swarmplot(x=df['Period'], y=df['C_str'], color='.25')
plt.ylabel('Concrete compressive strength')
plt.show()

# %%
names = ['Slag', 'Fly_ash', 'SuperP', 'w/c', 'agg','Age', 'Period', 'C_str']
df = df[names]
df_2 = df.drop(labels='Period',axis=1)
df_2
# Out:
#        Slag  Fly_ash  SuperP       w/c     agg  Age      C_str
# 0       0.0      0.0     2.5  0.300000  858.00   28  79.986111
# 1       0.0      0.0     2.5  0.300000  865.50   28  61.887366
# 2     142.5      0.0     0.0  0.685714  763.00  270  40.269535
# 3     142.5      0.0     0.0  0.685714  763.00  365  41.052780
# 4     132.4      0.0     0.0  0.966767  901.95  360  44.296075
# ...     ...      ...     ...       ...     ...  ...        ...
# 1025  116.0     90.3     8.9  0.649783  819.20   28  44.284354
# 1026    0.0    115.6    10.4  0.608318  815.65   28  31.178794
# 1027  139.4    108.6     6.1  1.297643  836.20   28  23.696601
# 1028  186.7      0.0    11.3  1.103708  889.25   28  32.768036
# 1029  100.5     78.3     8.6  0.768877  813.00   28  32.401235
#
# [1030 rows x 7 columns]

# %%
x = 'C_str'
fig = plt.figure(figsize=(12, 7))
for i in range(5):
    fig.add_subplot(2,3,1+i)
    y = names[i]
    sns.scatterplot(x=x,y=y, data = df, hue='Period')
    plt.xlabel('Concrete compressive strength')
plt.tight_layout()
plt.show()

# %%
df_2.corr()
# Out:
#              Slag   Fly_ash    SuperP       w/c       agg       Age     C_str
# Slag     1.000000 -0.323569  0.043376  0.357317 -0.441148 -0.044246  0.134824
# Fly_ash -0.323569  1.000000  0.377340  0.245994  0.054965 -0.154370 -0.105753
# SuperP   0.043376  0.377340  1.000000 -0.223417 -0.028320 -0.192717  0.366102
# w/c      0.357317  0.245994 -0.223417  1.000000  0.026439 -0.029268 -0.500700
# agg     -0.441148  0.054965 -0.028320  0.026439  1.000000 -0.125941 -0.259135
# Age     -0.044246 -0.154370 -0.192717 -0.029268 -0.125941  1.000000  0.328877
# C_str    0.134824 -0.105753  0.366102 -0.500700 -0.259135  0.328877  1.000000

# %%
sns.heatmap(df_2.corr(), cmap='Blues', annot = True)
# Out:
# <Axes: >

# %%
df_ = df==0
plt.barh(df_.sum().index, df_.sum())
plt.title('Number of Zeros')
plt.show()

# %%
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')
from sklearn.linear_model import SGDRegressor,GammaRegressor,Lasso,GammaRegressor,ElasticNet,Ridge
from sklearn.linear_model import RANSACRegressor,HuberRegressor, BayesianRidge,LinearRegression
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor, AdaBoostRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor # Decision Tree Regression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.pipeline import Pipeline # Streaming pipelines
from sklearn.model_selection import learning_curve, validation_curve, GridSearchCV # Model evaluation
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm

# %%
data = df_2.copy()

# %%
X=data.drop(columns='C_str')
Y=data['C_str']

# %%
X_ = sm.add_constant(X)
model1 = sm.OLS(Y,X_).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  C_str   R-squared:                       0.567
# Model:                            OLS   Adj. R-squared:                  0.564
# Method:                 Least Squares   F-statistic:                     223.1
# Date:                Fri, 08 Dec 2023   Prob (F-statistic):          6.17e-182
# Time:                        13:14:34   Log-Likelihood:                -3930.4
# No. Observations:                1030   AIC:                             7875.
# Df Residuals:                    1023   BIC:                             7909.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         48.0784      7.276      6.608      0.000      33.801      62.356
# ...

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.25, shuffle=True)

# %%
sc=StandardScaler()
X_train=sc.fit_transform(X_train) #each value is now its z-score
X_test=sc.transform(X_test)

# %%
lr=LinearRegression()
sgd=SGDRegressor()
lasso=Lasso()
ridge=Ridge()
rf=RandomForestRegressor()
dt=DecisionTreeRegressor()
gboost=GradientBoostingRegressor()
bagging=BaggingRegressor()
adboost=AdaBoostRegressor()
knn=KNeighborsRegressor()

# %%
algo=[lr,sgd,lasso,ridge,rf,dt,gboost,bagging,adboost,knn]

# %%
models=[]
accuracy_test=[]
accuracy_train=[]
for i in range(len(algo)):
    algo[i].fit(X_train,y_train)
    accuracy_train.append(algo[i].score(X_train,y_train))
    accuracy_test.append(algo[i].score(X_test,y_test))
    models.append(algo[i])

# %%
import torch
import torch.optim as optim
import torch.nn as nn

# %%
X_train=torch.Tensor(X_train)
y_train=torch.Tensor(y_train.to_numpy())
X_test=torch.Tensor(X_test)
y_test = torch.from_numpy(y_test.to_numpy())
y_test = torch.as_tensor(y_test)

# %%
class ANN(nn.Module):
  def __init__(self, input_size,hl1,hl2,output_size):
    super().__init__()
    self.l1=nn.Sequential(nn.Linear(input_size,hl1,bias=True), nn.ReLU())
    self.l2=nn.Sequential(nn.Linear(hl1,hl2,bias=True), nn.Sigmoid()) #linear layer with a relu activation function (output size = hl1)
    self.output=nn.Sequential(nn.Linear(hl2,output_size,bias=True)) #only linear layer with required output size i.e. 1 (for our case)

  def forward(self, x): #feeding forward
    data=x
    data=self.l1(data)
    data=self.l2(data)
    data=self.output(data)
    return data

# %%
input_size=6
hs1=24
hs2=24
output=1
model=ANN(input_size,hs1,hs2,output)

# %%
criterion=nn.MSELoss() #MSELoss is the loss function (Mean Squared Error)
optimizer=optim.AdamW(model.parameters(), lr=0.01)

# %%
from sklearn.metrics import r2_score

# %%
epochs=10000
losses=[]
acc=[]
for i in range(epochs):
  optimizer.zero_grad()
  outputs=model(X_train).squeeze()
  loss=criterion(outputs,y_train) #calculate loss
  loss.backward() #backpropagation
  optimizer.step()

  losses.append(loss.item())
  acc.append(r2_score(outputs.detach().numpy(),y_train.detach().numpy()))

  print('Epoch [{}/{}]'.format(i+1,epochs),' r2: {:.4f}'.format(acc[-1]))
# Out:
# Epoch [1/10000]  r2: 0.9586
# Epoch [2/10000]  r2: 0.9586
# Epoch [3/10000]  r2: 0.9585
# Epoch [4/10000]  r2: 0.9586
# Epoch [5/10000]  r2: 0.9586
# Epoch [6/10000]  r2: 0.9586
# Epoch [7/10000]  r2: 0.9585
# Epoch [8/10000]  r2: 0.9586
# Epoch [9/10000]  r2: 0.9585
# Epoch [10/10000]  r2: 0.9586
# Epoch [11/10000]  r2: 0.9585
# Epoch [12/10000]  r2: 0.9586
# Epoch [13/10000]  r2: 0.9585
# Epoch [14/10000]  r2: 0.9586
# Epoch [15/10000]  r2: 0.9586
# Epoch [16/10000]  r2: 0.9586
# Epoch [17/10000]  r2: 0.9586
# Epoch [18/10000]  r2: 0.9586
# Epoch [19/10000]  r2: 0.9586
# Epoch [20/10000]  r2: 0.9586
# Epoch [21/10000]  r2: 0.9586
# Epoch [22/10000]  r2: 0.9585
# Epoch [23/10000]  r2: 0.9586
# Epoch [24/10000]  r2: 0.9586
# Epoch [25/10000]  r2: 0.9586
# Epoch [26/10000]  r2: 0.9585
# Epoch [27/10000]  r2: 0.9586
# Epoch [28/10000]  r2: 0.9586
# Epoch [29/10000]  r2: 0.9586
# Epoch [30/10000]  r2: 0.9586
# Epoch [31/10000]  r2: 0.9586
# Epoch [32/10000]  r2: 0.9586
# ...

# %%
X_test=torch.Tensor(X_test)
y_test=torch.Tensor(y_test)
with torch.no_grad():
  predicted=model(X_test).squeeze()
  r2=r2_score(predicted.detach().numpy(), y_test.detach().numpy())
  print('Accuracy Score : {:4f}%'.format(r2*100))
# Out:
# Accuracy Score : 87.842435%

# %%
models.append('ANN')
accuracy_train.append(acc[-1])
accuracy_test.append(r2)

# %%
mod=pd.DataFrame([models,accuracy_train,accuracy_test]).T
mod.columns=['model','score_train','score_test']
mod
# Out:
#                                                 model score_train score_test
# 0                                  LinearRegression()    0.561297    0.57643
# 1                                      SGDRegressor()    0.561177   0.574985
# 2                                             Lasso()    0.532564   0.541232
# 3                                             Ridge()    0.561293   0.576363
# 4   (DecisionTreeRegressor(max_features=1.0, rando...      0.9854   0.923858
# 5                             DecisionTreeRegressor()    0.996124   0.869511
# 6   ([DecisionTreeRegressor(criterion='friedman_ms...     0.94461   0.919175
# 7   (DecisionTreeRegressor(random_state=866599924)...    0.977135   0.910619
# 8   (DecisionTreeRegressor(max_depth=3, random_sta...    0.815521   0.804205
# 9                               KNeighborsRegressor()    0.822394   0.747631
# 10                                                ANN    0.965128   0.878424

# %%
mod.score_test = mod.score_test.astype(float)
plt.figure(figsize=(7,7))
plt.barh(range(11), mod.score_test)
plt.yticks(range(11), mod.model)
plt.xlim(0.5,1)
for index, value in enumerate(mod.score_test):
    plt.text(value, index, str(round(value*100,2))+'%')
plt.show()

# %%
df_prediction = pd.read_excel('./prediction.xlsx', sheet_name = 'RMC')
df_prediction
# Out:
#    Slag  Fly_ash  SuperP       w/c    agg  Age  Experimental Value
# 0     0        0   8.075  0.498762  853.2   28              35.144
# 1     0        0   8.025  0.540940  850.2   28              37.352
# 2     0       20   8.125  0.528178  847.8   28              35.208

# %%
df_prediction_1 = sc.transform(df_prediction.iloc[:,:-1])

# %%
print(np.round(rf.predict(df_prediction_1),2))
# Out:
# [37.44 36.64 36.22]

# %%
df_prediction['Predicted Strength'] = rf.predict(df_prediction_1)
percent_error = np.abs(df_prediction['Predicted Strength']-df_prediction['Experimental Value'])/df_prediction['Experimental Value']*100
df_prediction['percent error'] = np.round(percent_error,2)
df_prediction.to_excel("./predicted_with_exp.xlsx")
